# %%
import pandas as pd

df = pd.read_csv('/Users/santiagoolvera/Desktop/ITAM/pols_pub2/HoyNoCircula/Datos/final/contaminantes.csv')
df2 = pd.read_csv('/Users/santiagoolvera/Desktop/ITAM/pols_pub2/HoyNoCircula/Datos/final/meteorologia.csv')

# %%
import pandas as pd

# Cargar tu DataFrame
df = pd.read_csv('/Users/santiagoolvera/Desktop/ITAM/pols_pub2/HoyNoCircula/Datos/final/meteorologia.csv')  # o usa pd.read_csv(io.StringIO(data)) si es un string

# Pivotear el DataFrame
df_pivot = df.pivot_table(
    index='date',
    columns='id_parameter',
    values='mean_meteorologia'
)

# Renombrar columnas para que tengan el sufijo '_mean'
df_pivot.columns = [f"{col}_mean" for col in df_pivot.columns]

# Resetear índice para volver a tener 'date' como columna
df_pivot = df_pivot.reset_index()

# Obtener una fila por fecha para la columna 'activacion_doble_no_circula'
activacion = df[['date', 'activacion_doble_no_circula']].drop_duplicates()

# Unir al DataFrame pivoteado
df_final = df_pivot.merge(activacion, on='date')

# Mostrar resultado

# %%
df_final.to_csv('/Users/santiagoolvera/Desktop/ITAM/pols_pub2/HoyNoCircula/Datos/final/meteorologia_pivot.csv', index=False)

# %%
df = pd.read_csv('/Users/santiagoolvera/Desktop/ITAM/pols_pub2/HoyNoCircula/Datos/final/contaminantes_pivot.csv')
df2 = pd.read_csv('/Users/santiagoolvera/Desktop/ITAM/pols_pub2/HoyNoCircula/Datos/final/meteorologia_pivot.csv')

# %%
##hacer un merge entre contaminantes y meteorologia usando date

df_merged = pd.merge(df, df2, on='date', how='inner')

# %%
##drop columna activacion_doble_no_circula_x

df_merged = df_merged.drop(columns=['activacion_doble_no_circula_x'])

# %%
## rename activacion_doble_no_circula_y a activacion_doble_no_circula

df_merged = df_merged.rename(columns={'activacion_doble_no_circula_y': 'activacion_doble_no_circula'})

# %%
df_merged.to_csv('/Users/santiagoolvera/Desktop/ITAM/pols_pub2/HoyNoCircula/Datos/final/contaminantes_meteorologia.csv', index=False)

# %%
df_merged
# Out:
#             date   CO_mean    NO_mean   NO2_mean   NOX_mean    O3_mean  \
# 0     01/01/2016  0.962269  13.831140  29.712719  43.567982  33.471014
# 1     01/01/2017  0.786278  10.640708  23.246018  33.861947  32.500627
# 2     01/01/2018  0.375547   4.737052  18.324701  23.061753  27.958204
# 3     01/01/2019  0.642419  12.617143  22.363946  35.441905  38.940387
# 4     01/01/2020  0.428817   9.031579  13.382716  22.637895  18.774803
# ...          ...       ...        ...        ...        ...        ...
# 3283  31/12/2020  0.230408   3.517588  12.048583  16.025126  31.654676
# 3284  31/12/2021  0.818687  26.126506  34.755892  62.401606  34.842342
# 3285  31/12/2022  0.434355  11.396040  18.532663  30.336634  18.123367
# 3286  31/12/2023  0.640400  14.996212  25.853333  41.941288  30.692308
# 3287  31/12/2024  0.767143  24.413361  34.373757  60.087683  37.928214
#
#        PM10_mean  PM2.5_mean  PMCO_mean   SO2_mean    RH_mean   TMP_mean  \
# ...
